# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
data_full = pd.read_json("cleaned_amp.json")

# %%
data = data_full.drop(['Target Activity_Viruses','NAME', 'SEQUENCE', 'SYNTHESIS TYPE', 'TARGET GROUP', 'TARGET OBJECT'],axis=1)

# %%
data_filledna = data.fillna(0)

# %%
# use the pandas .corr() method to compute pairwise correlations for the dataframe
corr = data.corr()
# visualise the data with seaborn
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.set_style(style = 'white')
f, ax = plt.subplots(figsize=(40, 26))
cmap = sns.diverging_palette(10, 250, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, 
        square=True,
        linewidths=.75, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Create interactive plot for better visualisation
heat = go.Heatmap(
    z = corr,
    x = corr.columns.values,
    y = corr.columns.values,
    zmin = - 0.5, # Sets the lower bound of the color domain
    zmax = 1,
    xgap = 1, # Sets the horizontal gap (in pixels) between bricks
    ygap = 1,
    colorscale = 'RdBu'
)

layout = go.Layout(
    title_text='Feature Correlation Matrix', 
    title_x=0.5, 
    width=2000, 
    height=2000,
    xaxis_showgrid=False,
    yaxis_showgrid=False,
    yaxis_autorange='reversed'
)

fig=go.Figure(data=[heat], layout=layout)
fig.update_xaxes(tickfont=dict(size=9))
fig.update_yaxes(tickfont=dict(size=9))
fig.show()
# Out:
# <div>                            <div id="38e00e85-c7ad-4c15-8feb-45a74ac9004b" class="plotly-graph-div" style="height:2000px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38e00e85-c7ad-4c15-8feb-45a74ac9004b")) {                    Plotly.newPlot(                        "38e00e85-c7ad-4c15-8feb-45a74ac9004b",                        [{"colorscale":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"x":["INTERCHAIN BOND - CHAIN 1","INTERCHAIN BOND - CHAIN 2","INTERCHAIN BOND - CHAIN 3","INTRACHAIN BOND - POSITION 1","INTRACHAIN BOND - POSITION 2","HEMOLITIC CYTOTOXIC ACTIVITY - ACTIVITY (\u03bcg/ml) (Calculated By DBAASP)","AV label","['N-term_']_(C5H5)2Ru","['N-term_']_12-GDA","['N-term_']_2MeACl","['N-term_']_3,5 Bis-(Meth)Tol","['N-term_']_3,5 Bis-(Meth)Tol,3,5 Bis-(Meth)Tol","['N-term_']_3-OH-5-ME-C6","['N-term_']_3-OH-C16","['N-term_']_3-OH-DiMe-C12","['N-term_']_3-OH-Me-C13","['N-term_']_3-OH-Me-C13,3-OH-DiMe-C13","['N-term_']_3-OH-Me-C14","['N-term_']_3-OH-Me-C14,3-OH-C16","['N-term_']_3MeACl","['N-term_']_7-ME-C8","['N-term_']_ACT","['N-term_']_ACT,ACT","['N-term_']_Abz","['N-term_']_BZO","['N-term_']_Boc","['N-term_']_C10","['N-term_']_C11:1","['N-term_']_C12","['N-term_']_C12,C12","['N-term_']_C14","['N-term_']_C14OH","['N-term_']_C16","['N-term_']_C18","['N-term_']_C5","['N-term_']_C6","['N-term_']_C7","['N-term_']_C8","['N-term_']_C8,C8","['N-term_']_C9","['N-term_']_CAA","['N-term_']_Ch","['N-term_']_Chol","['N-term_']_DNS","['N-term_']_DiMIQ","['N-term_']_FOR","['N-term_']_GUAN","['N-term_']_TOS","['N-term_']_VitE","['N-term_']_pHCA","Monomer","Multi-Peptide","Multimer","['C-term_']_8-Aoc-NH2","['C-term_']_AM","['C-term_']_AMD","['C-term_']_AMD,AMD","['C-term_']_BY","['C-term_']_C12H25-NH2","['C-term_']_C16-NH2","['C-term_']_CMK","['C-term_']_Chol","['C-term_']_Chol-NH2","['C-term_']_DiMIQ","['C-term_']_ETA","['C-term_']_MEA,MEA","['C-term_']_NME","['C-term_']_OBzl","['C-term_']_OEt","['C-term_']_OMe","['C-term_']_PEG4-Chol","['C-term_']_TA","['C-term_']_TDA","unusual/modified_aa__4 HYP","unusual/modified_aa__D-1-NAL","unusual/modified_aa__D-2-NAL","unusual/modified_aa__D-4-Cl-PHE","unusual/modified_aa__D-ALA","unusual/modified_aa__D-ARG","unusual/modified_aa__D-ASN","unusual/modified_aa__D-ASP","unusual/modified_aa__D-Allo-ILE","unusual/modified_aa__D-CYS","unusual/modified_aa__D-GLN","unusual/modified_aa__D-GLU","unusual/modified_aa__D-HIS","unusual/modified_aa__D-HYP","unusual/modified_aa__D-ILE","unusual/modified_aa__D-LAP","unusual/modified_aa__D-LEU","unusual/modified_aa__D-LYS","unusual/modified_aa__D-LYS-C10","unusual/modified_aa__D-LYS-C4","unusual/modified_aa__D-LYS-C6","unusual/modified_aa__D-MET","unusual/modified_aa__D-METH-Phe","unusual/modified_aa__D-NLE","unusual/modified_aa__D-ORN","unusual/modified_aa__D-PHE","unusual/modified_aa__D-PRO","unusual/modified_aa__D-PRO g-(S)a","unusual/modified_aa__D-PYA","unusual/modified_aa__D-SER","unusual/modified_aa__D-THR","unusual/modified_aa__D-TRP","unusual/modified_aa__D-TYR","unusual/modified_aa__D-Thr-GLC","unusual/modified_aa__D-VAL","DSB","Meta-TolB","SMB","[PEG4]2-Chol-B","DCB","DSB.1","LAC","LCB","Meta-TolB.1","NCB","Para-XylB","SMB.1","SSB","TIE","HELIX","TURN","SHEET","HYDROPHOBIC MOMENT","SEQUENCE CHARGE","CHARGE DENSITY","ISOELECTRIC POINT","INSTABILITY INDEX","AROMATICITY","ALIPHATIC INDEX","BOMAN INDEX","Target Activity_Bacteria","Target Activity_Eukaryota","Target Activity_Tumour","CYSTEINE COUNT","POLARITY","H-BONDING","BULKY PROPERTIES","COMPOSITIONAL CHARACTERISTIC INDEX","LOCAL FLEXIBILITY","ELECTRONIC PROPERTIES","HELIX BEND PREFERENCE" ...

# %%
# Drop features that have high correlations with other existing features
# Intuitively, it makes sense monomer vs multimer info is represented in info on interchain bonds
data_filt = data.drop(["INTERCHAIN BOND - CHAIN 2","Monomer","Multimer","DSB","TIE","['C-term_']_TA"], axis=1)

# %%
data_filt = data_filt.fillna(0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
# Spliiting data into test and train sets
X_train, X_test, y_train, y_test = train_test_split(data_filt.drop('AV label', axis=1), data_filt['AV label'], 
                                                    test_size=0.20, random_state=0)
# fitting the model
model = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)

# %%
# plotting feature importances
features = data_filt.drop('AV label', axis=1).columns
importances = model.feature_importances_
indices = np.argsort(importances)

# %%
plt.figure(figsize=(20,30))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# Create interactive plot for better visualisation
df = pd.DataFrame([features[i] for i in indices], columns=["Features"])
df["Relative Importance"] = importances[indices]
df.sort_values("Relative Importance", ascending=False, inplace=True, ignore_index=True)

fig = px.bar(df.iloc[:35], x="Relative Importance", y="Features",orientation='h',
                title="Feature Importances")
fig.update_layout(yaxis=dict(autorange="reversed"), title_x=0.5)
fig.update_yaxes(tickfont=dict(size=8))
fig.show()
# Out:
# <div>                            <div id="f4816817-6201-41b4-9164-a5ab9b5f3b98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4816817-6201-41b4-9164-a5ab9b5f3b98")) {                    Plotly.newPlot(                        "f4816817-6201-41b4-9164-a5ab9b5f3b98",                        [{"alignmentgroup":"True","hovertemplate":"Relative Importance=%{x}<br>Features=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.1357308032352679,0.06666064570432972,0.06622291327861599,0.06132733316807645,0.05536508582622974,0.030186256521356133,0.027439059852662342,0.025429186722621386,0.02479847475383211,0.024759417160771176,0.02421298901118726,0.023715438391491497,0.023482236457510006,0.023364852848261675,0.02300258323208864,0.02283720701789434,0.022604688020436754,0.0223306685159172,0.021928573872013846,0.021768210082822002,0.021661689590469345,0.021650669473991555,0.021507047762236674,0.021502718825187967,0.021325526595111423,0.02118472611495009,0.018855386721875957,0.018702242938159034,0.018245640314107473,0.015891004315893496,0.007776495678993278,0.007491885541965327,0.007135897093981785,0.006780307891052258,0.006485666281631573],"xaxis":"x","y":["Target Activity_Bacteria","SEQUENCE CHARGE","ISOELECTRIC POINT","CHARGE DENSITY","H-BONDING","ELECTRONIC PROPERTIES","MS-WHIM-3 SCORE","INSTABILITY INDEX","LOCAL FLEXIBILITY","MS-WHIM-2 SCORE","DOUBLE BEND PREFERENCE","HELIX BEND PREFERENCE","PARTIAL SPECIFIC VOLUME","MS-WHIM-1 SCORE","POLARITY","BOMAN INDEX","FLAT EXTENDED PREFERENCE","BULKY PROPERTIES","pK-C","COMPOSITIONAL CHARACTERISTIC INDEX","TURN","SHEET","SIDE CHAIN SIZE","HYDROPHOBIC MOMENT","EXTENDED STRUCTURAL PREFERENCE","ALIPHATIC INDEX","HEMOLITIC CYTOTOXIC ACTIVITY - ACTIVITY (\u03bcg/ml) (Calculated By DBAASP)","AROMATICITY","HELIX","Target Activity_Eukaryota","['N-term_']_ACT","INTRACHAIN BOND - POSITION 2","INTRACHAIN BOND - POSITION 1","CYSTEINE COUNT","['C-term_']_AMD"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %%
# select top 40 features
top_40 = np.argsort(importances)[-40:]
top_features = features[top_40]

# %%
selected_data = data_filt[list(top_features)+["AV label"]]

# %%
selected_data.to_json("selected_feats_amp.json", orient="records", indent=2)

# %%
selected_data = selected_data.join(data_full["SYNTHESIS TYPE"])

# %%
selected_feats_ribo = selected_data[selected_data["SYNTHESIS TYPE"] == "Ribosomal"]
selected_feats_synth = selected_data[selected_data["SYNTHESIS TYPE"] == "Synthetic"]

# %%
selected_feats_ribo.to_json("selected_feats_ribosomal.json")
selected_feats_synth.to_json("selected_feats_synthetic.json")

# %%
selected_feats_synth["AV label"].value_counts()
# Out:
# 0    10387
# 1      981
# Name: AV label, dtype: int64
